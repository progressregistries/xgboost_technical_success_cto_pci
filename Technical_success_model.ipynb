# %% [markdown]
# # Technical success model
#
# This notebook is a compact runner for the full cleaned pipeline in `Technical_success_model.py`. Edit `CONFIG` in that Python file to map the generic placeholders to your local dataset columns, then run the cells below.

# %%
# %pip install -q -r Technical_success_model_requirements.txt

# %%
from pathlib import Path
from Technical_success_model import CONFIG, run_pipeline

# Before running, replace TODO values in CONFIG inside Technical_success_model.py.
# Optional overrides can be set here, for example:
# CONFIG.data_path = Path('your_input_file.csv')
# CONFIG.run_loco = True

# %%
results = run_pipeline(CONFIG)
results['comparison']

# %%
results['calibrated_metrics']

# %%
results['clinical_scores']

# %%
results['fairness']
